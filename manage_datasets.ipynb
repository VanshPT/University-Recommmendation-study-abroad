# %%
import pandas as pd

# %%
dfUS=pd.read_csv('university_data.csv')
dfCANADA=pd.read_csv('university_data1.csv')

# %%
dfUS['country']='US'
dfUS['course']='CE/CS'
dfUS
# Out:
#      GRE Score  GPA  IELTS Score  Research Paper  University Ranking  \
# 0           51  0.5          3.7              55                  77
# 1          163  1.0          8.0              45                  66
# 2          176  1.2          4.9               7                  83
# 3          145  1.7          4.3              37                  67
# 4           44  2.2          2.3               5                  55
# ..         ...  ...          ...             ...                 ...
# 995        254  0.2          2.7              18                  88
# 996        301  0.9          7.3               4                  66
# 997        232  1.5          2.3              64                  24
# 998        142  2.3          8.2              79                  11
# 999        253  2.6          6.5              80                  86
#
#                                   University Name  Admit Probability country  \
# ...

# %%
dfCANADA['country']='CANADA'
dfCANADA['course']='CE/CS'
dfCANADA
# Out:
#      GRE Score  GPA  IELTS Score  Research Paper  University Ranking  \
# 0           45  1.6          4.9              20                  48
# 1          326  0.4          8.3              71                  66
# 2           25  3.6          5.4              50                  68
# 3          311  2.4          1.7              17                   2
# 4          243  2.9          2.5              66                  99
# ..         ...  ...          ...             ...                 ...
# 995         65  2.7          6.6              30                  64
# 996        159  3.6          4.4              51                  47
# 997         15  1.3          2.7              33                  35
# 998         70  1.9          2.4              10                  98
# 999        241  3.4          1.6              88                  35
#
#                         University Name  Admit Probability country course
# ...

# %%
dfUS = dfUS.iloc[:-1]
dfCANADA = dfCANADA.iloc[:-1]
dfUS.to_csv('testUS.csv')
dfCANADA.to_csv('testCANADA.csv')

# %%
df_combined = pd.concat([dfUS, dfCANADA], ignore_index=True)

# Save the combined DataFrame to a new CSV file
df_combined.to_csv('combined_data.csv', index=False)
